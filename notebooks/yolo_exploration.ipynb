# %%
import torch

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

results = model('../data/Challenge_Data/Assets/0a18978cdc8b64f900b0db6a297eb99d/_preview.png')

results.print()
results.show()
# Out:
# Using cache found in /home/mistir_nigusse/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-7-12 Python-3.8.10 torch-2.3.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# image 1/1: 900x600 1 person
# Speed: 6.1ms pre-process, 94.8ms inference, 0.8ms NMS per image at shape (1, 3, 640, 448)
# <PIL.Image.Image image mode=RGB size=600x900>
